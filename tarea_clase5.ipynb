# %%
# 1.Calculadora Simple: Crea un programa que solicite al usuario dos números y una operación 
# (suma, resta, multiplicación o división). Luego, utilizando estructuras condicionales (if, elif, else), 
# realiza la operación seleccionada e imprime el resultado.

num1=int(input("Ingrese primer numero"))
num2=int(input("Ingrese segundo numero"))
operacion=input("Seleccione una se las siguientes operaciones: suma, resta, multiplicacion o division")
if operacion == "suma":
    suma=num1+num2
    print("El resultado de la suma es:",suma)
elif operacion == "resta":
    resta=num1-num2
    print("El resultado de la resta es:",resta)
elif operacion == "multiplicacion":
    multiplicacion=num1*num2
    print("El resultado de la multiplicación es: ",multiplicacion)
elif operacion == "division":
    if num2 != 0:
        division=num1/num2
        print("El resultado de la division es:",division)
# Out:
# El resultado de la suma es: 16

# %%
# 2. Contador de Números Pares e Impares: Escribe un programa que recorra una lista de números del 1 al 20.
# Utilizando un bucle for, determina cuántos de estos números son pares y cuántos son impares. Al final, 
# imprime la cantidad de números pares e impares.
contador_pares=0
contador_impares=0

for i in range(1,21):
    if i % 2 == 0:
        contador_pares += 1
    else:
        contador_impares += 1
print("La cantidad de numeros pares es: ", contador_pares)
print("La cantidad de numeros pares es: ", contador_impares)
# Out:
# La cantidad de numeros pares es:  10
# La cantidad de numeros pares es:  10

# %%
# 3.Validación de Contraseña: Pide al usuario que ingrese una contraseña.
# Utiliza un bucle while para seguir solicitando la contraseña hasta que coincida con una contraseña predefinida 
# (por ejemplo, "python123"). Muestra un mensaje de éxito cuando la contraseña es correcta.
contraseña_correcta="python123"
contraseña=input("Ingrese la contraseña")
while contraseña!=contraseña_correcta:
    print("Contraseña incorrecta")
    contraseña=input("Ingrese la contraseña nuevamente")
print("Contraseña correcta")
# Out:
# Contraseña incorrecta
# Contraseña incorrecta
# Contraseña incorrecta
# Contraseña correcta

# %%
# 4.Identificador de Números Primos: Crea un programa que solicite al usuario un número entero. 
# Utilizando un bucle for, verifica si el número es primo (es decir, solo divisible por 1 y por sí mismo). 
# Imprime un mensaje indicando si el número es primo o no.
def analisis_de_primo(numero_ingresado):
    if numero_ingresado <= 1:
        return False
    for i in range(2, int(numero_ingresado**0.5) + 1):
        if numero_ingresado % i == 0:
            return False
    return True

numero_ingresado = int(input("Ingresa un número entero: "))
if analisis_de_primo(numero_ingresado):
    print(f"{numero_ingresado} es un número primo.")
else:
    print(f"{numero_ingresado} no es un número primo.")
# Out:
# 9 no es un número primo.

# %%
# 5. Juego de Adivinanza: Genera un número aleatorio entre 1 y 50. Pide al usuario que adivine el número. 
# Utiliza un bucle while para permitir múltiples intentos. Da pistas al usuario si el número ingresado es demasiado 
# alto o bajo. Finaliza el juego cuando el usuario adivine correctamente.

import random

def adivinanza():
    numero= random.randint(1, 50)
    intentos = 0

    while True:
        intentos += 1
        numero_usuario = int(input("Adivina el número entre 1 y 50: "))

        if numero_usuario < numero:
            print("¡Demasiado bajo! Intenta de nuevo.")
        elif numero_usuario > numero:
            print("¡Demasiado alto! Intenta de nuevo.")
        else:
            print(f"¡Bien hecho! Has adivinado el número en {intentos} intentos.")
            break

adivinanza()
# Out:
# ¡Demasiado alto! Intenta de nuevo.
# ¡Demasiado bajo! Intenta de nuevo.
# ¡Demasiado bajo! Intenta de nuevo.
# ¡Demasiado bajo! Intenta de nuevo.
# ¡Demasiado bajo! Intenta de nuevo.
# ¡Demasiado bajo! Intenta de nuevo.
# ¡Demasiado bajo! Intenta de nuevo.
# ¡Demasiado bajo! Intenta de nuevo.
# ¡Demasiado bajo! Intenta de nuevo.
# ¡Demasiado bajo! Intenta de nuevo.
# ¡Bien hecho! Has adivinado el número en 11 intentos.

# %%
# 6.Tabla de Multiplicar: Pide al usuario que ingrese un número entero. 
# Utiliza un bucle for para imprimir la tabla de multiplicar de ese número del 1 al 10. 
# Por ejemplo, si el usuario ingresa 7, el programa debe imprimir:

numero_entero=int(input("Ingrese un numero entero del 1 al 10 para saber su tabla de multiplicar"))
for t in range(1,11):
    print(f"{numero_entero} x {t} = {numero_entero*t}")
# Out:
# 10 x 1 = 10
# 10 x 2 = 20
# 10 x 3 = 30
# 10 x 4 = 40
# 10 x 5 = 50
# 10 x 6 = 60
# 10 x 7 = 70
# 10 x 8 = 80
# 10 x 9 = 90
# 10 x 10 = 100
